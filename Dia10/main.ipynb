# %%
fichero = open('dat.txt')
lista = []

for linea in fichero:
    lista.append(linea)
finalizado = False
linea = 0
ciclo = 0
X = 1
suma = 0
txt = ""
sprite = 1


while not finalizado:
    try:
        lista[linea] = lista[linea].split()
        ciclo += 1
        if ciclo == X or ciclo - 1 == X or ciclo + 1 == X:
            txt = txt + "#"

            if ciclo == 40 or ciclo == 80 or ciclo == 120 or ciclo == 160 or ciclo == 200 or ciclo == 240:
                txt = txt + "\n"            
        else:
            if ciclo <=40:
                txt = txt + "."
            elif ciclo > 41 and ciclo < 80:
                if ciclo - 40 == X or ciclo - 40 - 1 == X or ciclo - 40 + 1 == X:
                    txt = txt + "#"
                else:
                    txt = txt + "."
            elif ciclo > 81 and ciclo <120:
                if ciclo - 80 == X or ciclo - 80 - 1 == X or ciclo - 80 + 1 == X:
                    txt = txt + "#"
                else:
                    txt = txt + "."
            elif ciclo > 121 and ciclo <160:
                if ciclo - 120 == X or ciclo - 120 - 1 == X or ciclo - 120 + 1 == X:
                    txt = txt + "#"
                else:
                    txt = txt + "."
            elif ciclo > 161 and ciclo <200:
                if ciclo - 160 == X or ciclo - 160 - 1 == X or ciclo - 160 + 1 == X:
                    txt = txt + "#"
                else:  
                    txt = txt + "."
            
            elif ciclo > 201 and ciclo <240:
                if ciclo - 200 == X or ciclo - 200 - 1 == X or ciclo - 200 + 1 == X:
                    txt = txt + "#"
                else:
                    txt = txt + "."
        
            elif ciclo == 1 or ciclo == 41 or ciclo == 81 or ciclo == 121 or ciclo == 161 or ciclo == 201:
                if ciclo == 41:
                    if ciclo - 40 == X or ciclo - 40 - 1 == X or ciclo - 40 + 1 == X:
                        txt = txt + "#"
                    else:
                        txt = txt + "."
                elif ciclo == 81:
                    if ciclo - 80 == X or ciclo - 80 - 1 == X or ciclo - 80 + 1 == X:
                        txt = txt + "#"
                    else:
                        txt = txt + "."
                elif ciclo == 121:
                    if ciclo - 120 == X or ciclo - 120 - 1 == X or ciclo - 120 + 1 == X:
                        txt = txt + "#"
                    else:
                        txt = txt + "."
                elif ciclo == 161:
                    if ciclo - 160 == X or ciclo - 160 - 1 == X or ciclo - 160 + 1 == X:
                        txt = txt + "#"
                    else:
                        txt = txt + "."
                elif ciclo == 201:
                    if ciclo - 200 == X or ciclo - 200 - 1 == X or ciclo - 200 + 1 == X:
                        txt = txt + "#"
                    else:
                        txt = txt + "."
                else:
                    txt = txt + "."
            elif ciclo == 40 or ciclo == 80 or ciclo == 120 or ciclo == 160 or ciclo == 200 or ciclo == 240:
                if ciclo == 40:
                    if ciclo - 40 == X or ciclo - 40 - 1 == X or ciclo - 40 + 1 == X:
                        txt = txt + "#"
                    else:
                        txt = txt + "."
                elif ciclo == 80:
                    if ciclo - 80 == X or ciclo - 80 - 1 == X or ciclo - 80 + 1 == X:
                        txt = txt + "#"
                    else:
                        txt = txt + "."
                elif ciclo == 120:
                    if ciclo - 120 == X or ciclo - 120 - 1 == X or ciclo - 120 + 1 == X:
                        txt = txt + "#"
                    else:
                        txt = txt + "."
                elif ciclo == 160:
                    if ciclo - 160 == X or ciclo - 160 - 1 == X or ciclo - 160 + 1 == X:
                        txt = txt + "#"
                    else:
                        txt = txt + "."
                elif ciclo == 200:
                    if ciclo - 200 == X or ciclo - 200 - 1 == X or ciclo - 200 + 1 == X:
                        txt = txt + "#"
                    else:
                        txt = txt + "."
                elif ciclo == 240:
                    if ciclo - 240 == X or ciclo - 240 - 1 == X or ciclo - 240 + 1 == X:
                        txt = txt + "#"
                    else:
                        txt = txt + "."
            

            if ciclo == 40 or ciclo == 80 or ciclo == 120 or ciclo == 160 or ciclo == 200 or ciclo == 240:
                txt = txt + "\n"

        
        if lista[linea][0] == 'noop':
            if ciclo == 20 or ciclo == 60 or ciclo == 100 or ciclo == 140 or ciclo == 180 or ciclo == 220:
                suma += ciclo * X

        if lista[linea][0] == 'addx':
            if ciclo == 20 or ciclo == 60 or ciclo == 100 or ciclo == 140 or ciclo == 180 or ciclo == 220:
                suma += ciclo * X

            ciclo += 1
            if ciclo == X or ciclo - 1 == X or ciclo + 1 == X:
                txt = txt + "#"         
                if ciclo == 40 or ciclo == 80 or ciclo == 120 or ciclo == 160 or ciclo == 200 or ciclo == 240:
                    txt = txt + "\n"                
            else:
                
                if ciclo <= 40:
                    txt = txt + "."
                elif ciclo > 41 and ciclo < 80:
                    if ciclo - 40 == X or ciclo - 40 - 1 == X or ciclo - 40 + 1 == X:
                        txt = txt + "#"
                    else:
                        txt = txt + "."
                elif ciclo > 81 and ciclo <120:
                    if ciclo - 80 == X or ciclo - 80 - 1 == X or ciclo - 80 + 1 == X:
                        txt = txt + "#"
                    else:
                        txt = txt + "."
                    
                    
                elif ciclo > 121 and ciclo <160:
                    if ciclo - 120 == X or ciclo - 120 - 1 == X or ciclo - 120 + 1 == X:
                        txt = txt + "#"
                    else:
                        txt = txt + "."

                elif ciclo > 161 and ciclo <200:
                    if ciclo - 160 == X or ciclo - 160 - 1 == X or ciclo - 160 + 1 == X:
                        txt = txt + "#"
                    else:
                        txt = txt + "."
                
                elif ciclo > 201 and ciclo < 240:
                    if ciclo - 200 == X or ciclo - 200 - 1 == X or ciclo - 200 + 1 == X:
                        txt = txt + "#"
                    else:
                        txt = txt + "."

        
                elif ciclo == 1 or ciclo == 41 or ciclo == 81 or ciclo == 121 or ciclo == 161 or ciclo == 201:
                    if ciclo == 1:
                        if ciclo == X or ciclo + 1 == X:
                            txt = txt + "#"
                        else:
                            txt = txt + "."
                    if ciclo == 41:
                        if ciclo - 40 == X or ciclo - 40 - 1 == X or ciclo - 40 + 1 == X:
                            txt = txt + "#"
                        else:
                            txt = txt + "."
                    elif ciclo == 81:
                        if ciclo - 80 == X or ciclo - 80 - 1 == X or ciclo - 80 + 1 == X:
                            txt = txt + "#"
                        else:
                            txt = txt + "."
                    elif ciclo == 121:
                        if ciclo - 120 == X or ciclo - 120 - 1 == X or ciclo - 120 + 1 == X:
                            txt = txt + "#"
                        else:
                            txt = txt + "."
                    elif ciclo == 161:
                        if ciclo - 160 == X or ciclo - 160 - 1 == X or ciclo - 160 + 1 == X:
                            txt = txt + "#"
                        else:
                            txt = txt + "."
                    elif ciclo == 201:
                        if ciclo - 200 == X or ciclo - 200 - 1 == X or ciclo - 200 + 1 == X:
                            txt = txt + "#"
                        else:
                            txt = txt + "."
                    else:
                        txt = txt + "."
                elif ciclo == 40 or ciclo == 80 or ciclo == 120 or ciclo == 160 or ciclo == 200 or ciclo == 240:
                    if ciclo == 40:
                        if ciclo - 40 == X or ciclo - 40 - 1 == X or 1 == X:
                            txt = txt + "#"
                        else:
                            txt = txt + "."
                    elif ciclo == 80:
                        if ciclo - 80 == X or ciclo - 80 - 1 == X or 1 == X:
                            txt = txt + "#"
                        else:
                            txt = txt + "."
                    elif ciclo == 120:
                        if ciclo - 120 == X or ciclo - 120 - 1 == X or 1 == X:
                            txt = txt + "#"
                        else:
                            txt = txt + "."
                    elif ciclo == 160:
                        if ciclo - 160 == X or ciclo - 160 - 1 == X or 1 == X:
                            txt = txt + "#"
                        else:
                            txt = txt + "."
                    elif ciclo == 200:
                        if ciclo - 200 == X or ciclo - 200 - 1 == X or 1 == X:
                            txt = txt + "#"
                        else:
                            txt = txt + "."
                    elif ciclo == 240:
                        if ciclo - 240 == X or ciclo - 240 - 1 == X or ciclo - 240 + 1 == X:
                            txt = txt + "#"
                        else:
                            txt = txt + "."
                

                            
                        
                if ciclo == 40 or ciclo == 80 or ciclo == 120 or ciclo == 160 or ciclo == 200 or ciclo == 240:
                    txt = txt + "\n"                                   
            if ciclo == 20 or ciclo == 60 or ciclo == 100 or ciclo == 140 or ciclo == 180 or ciclo == 220:
                print(ciclo * X)
                print(X)
                print("-------------")
                suma += ciclo * X            
            X += int(lista[linea][1])


        linea += 1
    except IndexError:
        finalizado = True
print(suma)
print(txt)
# Out:
# 3960
# 18
# -------------
# 13140
# ##..##..#..##...##.##..##..##..##..##...
# ###..####..###...###...####..####..###..
# ##.....#####...###.....####.....##.....#
# ####.....##.#......#####.....####.......
# ###.##.....##.###......######......##.#.
# ###.##.......####.#........########.....

# %%
fichero = open('datos.txt')
lista = []

for linea in fichero:
    lista.append(linea)
finalizado = False
linea = 0
ciclo = 0
X = 1
suma = 0
txt = ""
sprite = 1
posicion = 0


while not finalizado:
    try:
        lista[linea] = lista[linea].split()
        ciclo += 1

        if sprite - 1 == ciclo - 1 or sprite + 1 == ciclo - 1 or sprite == ciclo - 1:
            txt = txt + "#"
        elif sprite - 1 + 40  == ciclo - 1 or sprite + 1 + 40 == ciclo -1 or sprite + 40 == ciclo-1:
            txt = txt + "#"
        elif sprite - 1 + 80  == ciclo - 1 or sprite + 1 + 80 == ciclo -1 or sprite + 80 == ciclo-1:
            txt = txt + "#"
        elif sprite - 1 + 120  == ciclo - 1 or sprite + 1 + 120 == ciclo-1  or sprite + 120 == ciclo-1:
            txt = txt + "#"
        elif sprite - 1 + 160  == ciclo - 1 or sprite + 1 + 160 == ciclo-1  or sprite + 160 == ciclo-1:
            txt = txt + "#"
        elif sprite - 1 + 200  == ciclo - 1 or sprite + 1 + 200 == ciclo-1  or sprite + 200 == ciclo-1:
            txt = txt + "#"
        else:
            txt = txt + "."


        if ciclo == 40 or ciclo == 80 or ciclo == 120 or ciclo == 160 or ciclo == 200 or ciclo == 240:
            txt = txt + "\n"
       
        if lista[linea][0] == 'addx':
            ciclo += 1

            if sprite - 1 == ciclo - 1 or sprite + 1 == ciclo - 1 or sprite == ciclo - 1:
                txt = txt + "#"
            elif sprite - 1 + 40  == ciclo - 1 or sprite + 1 + 40 == ciclo -1 or sprite + 40 == ciclo-1:
                txt = txt + "#"
            elif sprite - 1 + 80  == ciclo - 1 or sprite + 1 + 80 == ciclo -1 or sprite + 80 == ciclo-1:
                txt = txt + "#"
            elif sprite - 1 + 120  == ciclo - 1 or sprite + 1 + 120 == ciclo-1  or sprite + 120 == ciclo-1:
                txt = txt + "#"
            elif sprite - 1 + 160  == ciclo - 1 or sprite + 1 + 160 == ciclo-1  or sprite + 160 == ciclo-1:
                txt = txt + "#"
            elif sprite - 1 + 200  == ciclo - 1 or sprite + 1 + 200 == ciclo-1  or sprite + 200 == ciclo-1:
                txt = txt + "#"
            else:
                txt = txt + "."
            if ciclo == 40 or ciclo == 80 or ciclo == 120 or ciclo == 160 or ciclo == 200 or ciclo == 240:
                txt = txt + "\n"
            X += int(lista[linea][1])
            sprite = sprite + int(lista[linea][1])

        linea += 1
    except IndexError:
        finalizado = True
print(txt)
# Out:
# ####..##..####.#..#.####..##..#....###.#
# #....#..#....#.#..#....#.#..#.#....#..#.
# ###..#......#..#..#...#..#..#.#....#..#.
# #....#.....#...#..#..#...####.#....###..
# #....#..#.#....#..#.#....#..#.#....#.###
# ####..##..####..##..####.#..#.####.#..#.
