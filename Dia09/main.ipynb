# %%
fichero = open('datos.txt')
lista = []

for linea in fichero:
    lista.append(linea)
finalizado = False
linea = 0

import numpy as np
array = np.zeros((2000, 2000))
posiciones_visitadas_tail = []
posicion_tail = [1000, 1000]
posicion_head = [1000, 1000]

while not finalizado:
    try:
        lista[linea] = lista[linea].split()
        if lista[linea][0] == 'U':
            for i in range(posicion_head[0], posicion_head[0] + int(lista[linea][1]) + 1):
                posicion_head[0]  = i
                while abs(posicion_head[0] - posicion_tail[0]) > 1 or abs(posicion_head[1] - posicion_tail[1]) > 1: #movemos tail para que no haya más de 1 de diferencia
                    if posicion_head[0] - posicion_tail[0] > 1 and posicion_head[1] - posicion_tail[1] == 1:
                        posicion_tail[0] += 1
                        posicion_tail[1] += 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] - posicion_tail[0] > 1 and posicion_head[1] - posicion_tail[1] == -1:
                        posicion_tail[0] += 1
                        posicion_tail[1] -= 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] - posicion_tail[0] < -1 and posicion_head[1] - posicion_tail[1] == 1:
                        posicion_tail[0] -= 1
                        posicion_tail[1] += 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] - posicion_tail[0] < -1 and posicion_head[1] - posicion_tail[1] == -1:
                        posicion_tail[0] -= 1
                        posicion_tail[1] -= 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] == 1 and posicion_head[1] - posicion_tail[1] > 1:
                        posicion_tail[0] += 1
                        posicion_tail[1] += 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] == 1 and posicion_head[1] - posicion_tail[1] < -1:
                        posicion_tail[0] += 1
                        posicion_tail[1] -= 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] == -1 and posicion_head[1] - posicion_tail[1] > 1:
                        posicion_tail[0] -= 1
                        posicion_tail[1] += 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] == -1 and posicion_head[1] - posicion_tail[1] < -1:
                        posicion_tail[0] -= 1
                        posicion_tail[1] -= 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())                        
                    if posicion_head[0] - posicion_tail[0] > 1:
                        posicion_tail[0] += 1
                    elif posicion_head[0] -  posicion_tail[0] < -1:
                        posicion_tail[0] -= 1
                    if posicion_head[1] - posicion_tail[1] > 1:
                        posicion_tail[1] += 1
                    elif posicion_head[1] -  posicion_tail[1] < -1:
                        posicion_tail[1] -= 1
                    posiciones_visitadas_tail.append(posicion_tail.copy())
        elif lista[linea][0] == 'D':
            for i in range(posicion_head[0], posicion_head[0] - int(lista[linea][1]) - 1, -1):
                posicion_head[0] = i
                while abs(posicion_head[0] - posicion_tail[0]) > 1 or abs(posicion_head[1] - posicion_tail[1]) > 1:
                    if posicion_head[0] -  posicion_tail[0] > 1 and posicion_head[1] - posicion_tail[1] == 1:
                        posicion_tail[0] += 1
                        posicion_tail[1] += 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] > 1 and posicion_head[1] - posicion_tail[1] == -1:
                        posicion_tail[0] += 1
                        posicion_tail[1] -= 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] < -1 and posicion_head[1] - posicion_tail[1] == 1:
                        posicion_tail[0] -= 1
                        posicion_tail[1] += 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] < -1 and posicion_head[1] - posicion_tail[1] == -1:
                        posicion_tail[0] -= 1
                        posicion_tail[1] -= 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] == 1 and posicion_head[1] - posicion_tail[1] > 1:
                        posicion_tail[0] += 1
                        posicion_tail[1] += 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] == 1 and posicion_head[1] - posicion_tail[1] < -1:
                        posicion_tail[0] += 1
                        posicion_tail[1] -= 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] == -1 and posicion_head[1] - posicion_tail[1] > 1:
                        posicion_tail[0] -= 1
                        posicion_tail[1] += 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] == -1 and posicion_head[1] - posicion_tail[1] < -1:
                        posicion_tail[0] -= 1
                        posicion_tail[1] -= 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())                        
                    if posicion_head[0] -  posicion_tail[0] > 1:
                        posicion_tail[0] += 1
                    elif posicion_head[0] -  posicion_tail[0] < -1:
                        posicion_tail[0] -= 1
                    if posicion_head[1] -  posicion_tail[1] > 1:
                        posicion_tail[1] += 1
                    elif posicion_head[1] -  posicion_tail[1] < -1:
                        posicion_tail[1] -= 1
                    posiciones_visitadas_tail.append(posicion_tail.copy())

        elif lista[linea][0] == 'L':
            for i in range(posicion_head[1], posicion_head[1] - int(lista[linea][1]) - 1, -1):
                posicion_head[1] = i
                while abs(posicion_head[0] - posicion_tail[0]) > 1 or abs(posicion_head[1] - posicion_tail[1]) > 1:
                    if posicion_head[0] -  posicion_tail[0] > 1 and posicion_head[1] - posicion_tail[1] == 1:
                        posicion_tail[0] += 1
                        posicion_tail[1] += 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] > 1 and posicion_head[1] - posicion_tail[1] == -1:
                        posicion_tail[0] += 1
                        posicion_tail[1] -= 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] < -1 and posicion_head[1] - posicion_tail[1] == 1:
                        posicion_tail[0] -= 1
                        posicion_tail[1] += 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] < -1 and posicion_head[1] - posicion_tail[1] == -1:
                        posicion_tail[0] -= 1
                        posicion_tail[1] -= 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] == 1 and posicion_head[1] - posicion_tail[1] > 1:
                        posicion_tail[0] += 1
                        posicion_tail[1] += 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] == 1 and posicion_head[1] - posicion_tail[1] < -1:
                        posicion_tail[0] += 1
                        posicion_tail[1] -= 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] == -1 and posicion_head[1] - posicion_tail[1] > 1:
                        posicion_tail[0] -= 1
                        posicion_tail[1] += 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] == -1 and posicion_head[1] - posicion_tail[1] < -1:
                        posicion_tail[0] -= 1
                        posicion_tail[1] -= 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())                        
                    if posicion_head[0] -  posicion_tail[0] > 1:
                        posicion_tail[0] += 1
                    elif posicion_head[0] -  posicion_tail[0] < -1:
                        posicion_tail[0] -= 1
                    if posicion_head[1] -  posicion_tail[1] > 1:
                        posicion_tail[1] += 1
                    elif posicion_head[1] -  posicion_tail[1] < -1:
                        posicion_tail[1] -= 1
                    posiciones_visitadas_tail.append(posicion_tail.copy())

        elif lista[linea][0] == 'R':
            for i in range(posicion_head[1], posicion_head[1] + int(lista[linea][1]) + 1):
                posicion_head[1] = i
                while abs(posicion_head[0] - posicion_tail[0]) > 1 or abs(posicion_head[1] - posicion_tail[1]) > 1:
                    if posicion_head[0] -  posicion_tail[0] > 1 and posicion_head[1] - posicion_tail[1] == 1:
                        posicion_tail[0] += 1
                        posicion_tail[1] += 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] > 1 and posicion_head[1] - posicion_tail[1] == -1:
                        posicion_tail[0] += 1
                        posicion_tail[1] -= 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] < -1 and posicion_head[1] - posicion_tail[1] == 1:
                        posicion_tail[0] -= 1
                        posicion_tail[1] += 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] < -1 and posicion_head[1] - posicion_tail[1] == -1:
                        posicion_tail[0] -= 1
                        posicion_tail[1] -= 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] == 1 and posicion_head[1] - posicion_tail[1] > 1:
                        posicion_tail[0] += 1
                        posicion_tail[1] += 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] == 1 and posicion_head[1] - posicion_tail[1] < -1:
                        posicion_tail[0] += 1
                        posicion_tail[1] -= 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] == -1 and posicion_head[1] - posicion_tail[1] > 1:
                        posicion_tail[0] -= 1
                        posicion_tail[1] += 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    elif posicion_head[0] -  posicion_tail[0] == -1 and posicion_head[1] - posicion_tail[1] < -1:
                        posicion_tail[0] -= 1
                        posicion_tail[1] -= 1
                        posiciones_visitadas_tail.append(posicion_tail.copy())
                    if posicion_head[0] -  posicion_tail[0] > 1:
                        posicion_tail[0] += 1
                    elif posicion_head[0] -  posicion_tail[0] < -1:
                        posicion_tail[0] -= 1
                    if posicion_head[1] -  posicion_tail[1] > 1:
                        posicion_tail[1] += 1
                    elif posicion_head[1] -  posicion_tail[1] < -1:
                        posicion_tail[1] -= 1
                    posiciones_visitadas_tail.append(posicion_tail.copy())
        linea += 1
    except:
        finalizado = True

posiciones_visitadas_tail.append([1000, 1000])
solucion = []
for i in posiciones_visitadas_tail:
    if i not in solucion:
        solucion.append(i)
print(len(solucion))
# Out:
# 6311

# %%
fichero = open('datos.txt')
lista = []

for linea in fichero:
    lista.append(linea)
finalizado = False
linea = 0

import numpy as np
array = np.zeros((2000, 2000))
posiciones_visitadas_tail = []
posicion_head = [1000, 1000]
posicion_1 = [1000, 1000]
posicion_2 = [1000, 1000]
posicion_3 = [1000, 1000]
posicion_4 = [1000, 1000]
posicion_5 = [1000, 1000]
posicion_6 = [1000, 1000]
posicion_7 = [1000, 1000]
posicion_8 = [1000, 1000]
posicion_tail = [1000, 1000]

nombre_cuerda = [posicion_head, posicion_1, posicion_2, posicion_3, posicion_4, posicion_5, posicion_6, posicion_7, posicion_8, posicion_tail]
while not finalizado:
    try:
        lista[linea] = lista[linea].split()

        if lista[linea][0] == 'U':
            for i in range(nombre_cuerda[0][0], nombre_cuerda[0][0] + int(lista[linea][1]) + 1):

                nombre_cuerda[0] = [i, nombre_cuerda[0][1]]
                k = 0
                for j in nombre_cuerda:
                    if k != 9 and k != 0:
                        while abs(nombre_cuerda[k - 1][0] - j[0]) > 1 or abs(nombre_cuerda[k - 1][1] - j[1]) > 1: #movemos tail para que no haya más de 1 de diferencia
                            if nombre_cuerda[k - 1][0] - j[0] > 1 and nombre_cuerda[k - 1][1] - j[1] == 1:
                                j[0] += 1
                                j[1] += 1
                            elif nombre_cuerda[k - 1][0] - j[0] > 1 and nombre_cuerda[k - 1][1] -j[1] == -1:
                                j[0] += 1
                                j[1] -= 1
                            elif nombre_cuerda[k - 1][0] - j[0] < -1 and nombre_cuerda[k - 1][1] - j[1] == 1:
                                j[0] -= 1
                                j[1] += 1
                            elif nombre_cuerda[k - 1][0] - j[0] < -1 and nombre_cuerda[k - 1][1] - j[1] == -1:
                                j[0] -= 1
                                j[1] -= 1
                            elif nombre_cuerda[k - 1][0] -  j[0] == 1 and nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[0] += 1
                                j[1] += 1
                            elif nombre_cuerda[k - 1][0] -  j[0] == 1 and nombre_cuerda[k - 1][1] - j[1] < -1:
                                j[0] += 1
                                j[1] -= 1
                            elif nombre_cuerda[k - 1][0] -  j[0] == -1 and nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[0] -= 1
                                j[1] += 1
                            elif nombre_cuerda[k - 1][0] -  j[0] == -1 and nombre_cuerda[k - 1][1] - j[1] < -1:
                                j[0] -= 1
                                j[1] -= 1
                            if nombre_cuerda[k - 1][0] - j[0] > 1:
                                j[0] += 1
                            elif nombre_cuerda[k - 1][0] -  j[0] < -1:
                                j[0] -= 1
                            if nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[1] += 1
                            elif nombre_cuerda[k - 1][1] -  j[1] < -1:
                                j[1] -= 1
                    if k == 9:
                        while abs(nombre_cuerda[k - 1][0] - j[0]) > 1 or abs(nombre_cuerda[k - 1][1] - j[1]) > 1: #movemos tail para que no haya más de 1 de diferencia
                            if nombre_cuerda[k - 1][0] - j[0] > 1 and nombre_cuerda[k - 1][1] - j[1] == 1:
                                j[0] += 1
                                j[1] += 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] - j[0] > 1 and nombre_cuerda[k - 1][1] -j[1] == -1:
                                j[0] += 1
                                j[1] -= 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] - j[0] < -1 and nombre_cuerda[k - 1][1] - j[1] == 1:
                                j[0] -= 1
                                j[1] += 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] - j[0] < -1 and nombre_cuerda[k - 1][1] - j[1] == -1:
                                j[0] -= 1
                                j[1] -= 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] -  j[0] == 1 and nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[0] += 1
                                j[1] += 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] -  j[0] == 1 and nombre_cuerda[k - 1][1] - j[1] < -1:
                                j[0] += 1
                                j[1] -= 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] -  j[0] == -1 and nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[0] -= 1
                                j[1] += 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] -  j[0] == -1 and nombre_cuerda[k - 1][1] - j[1] < -1:
                                j[0] -= 1
                                j[1] -= 1
                                posiciones_visitadas_tail.append(j.copy())
                            if nombre_cuerda[k - 1][0] - j[0] > 1:
                                j[0] += 1
                            elif nombre_cuerda[k - 1][0] -  j[0] < -1:
                                j[0] -= 1
                            if nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[1] += 1
                            elif nombre_cuerda[k - 1][1] -  j[1] < -1:
                                j[1] -= 1
                            posiciones_visitadas_tail.append(j.copy())

                    k += 1
        
            print("linea", linea, "nombre_cuerda", nombre_cuerda)
        
        elif lista[linea][0] == 'D':
            for i in range(nombre_cuerda [0][0], nombre_cuerda [0][0] - int(lista[linea][1]) - 1, -1):
                nombre_cuerda[0] = [i, nombre_cuerda[0][1]]
                k = 0
                for j in nombre_cuerda:
                    if k != 9 and k != 0:
                        while abs(nombre_cuerda[k - 1][0] - j[0]) > 1 or abs(nombre_cuerda[k - 1][1] - j[1]) > 1: #movemos tail para que no haya más de 1 de diferencia
                            if nombre_cuerda[k - 1][0] - j[0] > 1 and nombre_cuerda[k - 1][1] - j[1] == 1:
                                j[0] += 1
                                j[1] += 1
                            elif nombre_cuerda[k - 1][0] - j[0] > 1 and nombre_cuerda[k - 1][1] -j[1] == -1:
                                j[0] += 1
                                j[1] -= 1
                            elif nombre_cuerda[k - 1][0] - j[0] < -1 and nombre_cuerda[k - 1][1] - j[1] == 1:
                                j[0] -= 1
                                j[1] += 1
                            elif nombre_cuerda[k - 1][0] - j[0] < -1 and nombre_cuerda[k - 1][1] - j[1] == -1:
                                j[0] -= 1
                                j[1] -= 1
                            elif nombre_cuerda[k - 1][0] -  j[0] == 1 and nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[0] += 1
                                j[1] += 1
                            elif nombre_cuerda[k - 1][0] -  j[0] == 1 and nombre_cuerda[k - 1][1] - j[1] < -1:
                                j[0] += 1
                                j[1] -= 1
                            elif nombre_cuerda[k - 1][0] -  j[0] == -1 and nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[0] -= 1
                                j[1] += 1
                            elif nombre_cuerda[k - 1][0] -  j[0] == -1 and nombre_cuerda[k - 1][1] - j[1] < -1:
                                j[0] -= 1
                                j[1] -= 1
                            if nombre_cuerda[k - 1][0] - j[0] > 1:
                                j[0] += 1
                            elif nombre_cuerda[k - 1][0] -  j[0] < -1:
                                j[0] -= 1
                            if nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[1] += 1
                            elif nombre_cuerda[k - 1][1] -  j[1] < -1:
                                j[1] -= 1
                    if k == 9:
                        while abs(nombre_cuerda[k - 1][0] - j[0]) > 1 or abs(nombre_cuerda[k - 1][1] - j[1]) > 1: #movemos tail para que no haya más de 1 de diferencia
                            if nombre_cuerda[k - 1][0] - j[0] > 1 and nombre_cuerda[k - 1][1] - j[1] == 1:
                                j[0] += 1
                                j[1] += 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] - j[0] > 1 and nombre_cuerda[k - 1][1] -j[1] == -1:
                                j[0] += 1
                                j[1] -= 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] - j[0] < -1 and nombre_cuerda[k - 1][1] - j[1] == 1:
                                j[0] -= 1
                                j[1] += 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] - j[0] < -1 and nombre_cuerda[k - 1][1] - j[1] == -1:
                                j[0] -= 1
                                j[1] -= 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] -  j[0] == 1 and nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[0] += 1
                                j[1] += 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] -  j[0] == 1 and nombre_cuerda[k - 1][1] - j[1] < -1:
                                j[0] += 1
                                j[1] -= 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] -  j[0] == -1 and nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[0] -= 1
                                j[1] += 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] -  j[0] == -1 and nombre_cuerda[k - 1][1] - j[1] < -1:
                                j[0] -= 1
                                j[1] -= 1
                                posiciones_visitadas_tail.append(j.copy())
                            if nombre_cuerda[k - 1][0] - j[0] > 1:
                                j[0] += 1
                            elif nombre_cuerda[k - 1][0] -  j[0] < -1:
                                j[0] -= 1
                            if nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[1] += 1
                            elif nombre_cuerda[k - 1][1] -  j[1] < -1:
                                j[1] -= 1
                            posiciones_visitadas_tail.append(j.copy())


                    k += 1
            print("linea", linea, "nombre_cuerda", nombre_cuerda)
                
        elif lista[linea][0] == "R":
            for i in range (nombre_cuerda [0][1], nombre_cuerda [0][1] + int(lista[linea][1]) + 1):
                nombre_cuerda[0] = [nombre_cuerda[0][0], i]
                k = 0
                for j in nombre_cuerda:
                    if k != 9 and k != 0:
                        while abs(nombre_cuerda[k - 1][0] - j[0]) > 1 or abs(nombre_cuerda[k - 1][1] - j[1]) > 1: #movemos tail para que no haya más de 1 de diferencia
                            if nombre_cuerda[k - 1][0] - j[0] > 1 and nombre_cuerda[k - 1][1] - j[1] == 1:
                                j[0] += 1
                                j[1] += 1
                            elif nombre_cuerda[k - 1][0] - j[0] > 1 and nombre_cuerda[k - 1][1] -j[1] == -1:
                                j[0] += 1
                                j[1] -= 1
                            elif nombre_cuerda[k - 1][0] - j[0] < -1 and nombre_cuerda[k - 1][1] - j[1] == 1:
                                j[0] -= 1
                                j[1] += 1
                            elif nombre_cuerda[k - 1][0] - j[0] < -1 and nombre_cuerda[k - 1][1] - j[1] == -1:
                                j[0] -= 1
                                j[1] -= 1
                            elif nombre_cuerda[k - 1][0] -  j[0] == 1 and nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[0] += 1
                                j[1] += 1
                            elif nombre_cuerda[k - 1][0] -  j[0] == 1 and nombre_cuerda[k - 1][1] - j[1] < -1:
                                j[0] += 1
                                j[1] -= 1
                            elif nombre_cuerda[k - 1][0] -  j[0] == -1 and nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[0] -= 1
                                j[1] += 1
                            elif nombre_cuerda[k - 1][0] -  j[0] == -1 and nombre_cuerda[k - 1][1] - j[1] < -1:
                                j[0] -= 1
                                j[1] -= 1
                            if nombre_cuerda[k - 1][0] - j[0] > 1:
                                j[0] += 1
                            elif nombre_cuerda[k - 1][0] -  j[0] < -1:
                                j[0] -= 1
                            if nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[1] += 1
                            elif nombre_cuerda[k - 1][1] -  j[1] < -1:
                                j[1] -= 1
                    if k == 9:
                        while abs(nombre_cuerda[k - 1][0] - j[0]) > 1 or abs(nombre_cuerda[k - 1][1] - j[1]) > 1: #movemos tail para que no haya más de 1 de diferencia
                            if nombre_cuerda[k - 1][0] - j[0] > 1 and nombre_cuerda[k - 1][1] - j[1] == 1:
                                j[0] += 1
                                j[1] += 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] - j[0] > 1 and nombre_cuerda[k - 1][1] -j[1] == -1:
                                j[0] += 1
                                j[1] -= 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] - j[0] < -1 and nombre_cuerda[k - 1][1] - j[1] == 1:
                                j[0] -= 1
                                j[1] += 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] - j[0] < -1 and nombre_cuerda[k - 1][1] - j[1] == -1:
                                j[0] -= 1
                                j[1] -= 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] -  j[0] == 1 and nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[0] += 1
                                j[1] += 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] -  j[0] == 1 and nombre_cuerda[k - 1][1] - j[1] < -1:
                                j[0] += 1
                                j[1] -= 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] -  j[0] == -1 and nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[0] -= 1
                                j[1] += 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] -  j[0] == -1 and nombre_cuerda[k - 1][1] - j[1] < -1:
                                j[0] -= 1
                                j[1] -= 1
                                posiciones_visitadas_tail.append(j.copy())
                            if nombre_cuerda[k - 1][0] - j[0] > 1:
                                j[0] += 1
                            elif nombre_cuerda[k - 1][0] -  j[0] < -1:
                                j[0] -= 1
                            if nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[1] += 1
                            elif nombre_cuerda[k - 1][1] -  j[1] < -1:
                                j[1] -= 1
                            posiciones_visitadas_tail.append(j.copy())


                    k += 1
            print("linea", linea, "nombre_cuerda", nombre_cuerda)

        elif lista[linea][0] == "L":
            for i in range (nombre_cuerda [0][1], nombre_cuerda [0][1] - int(lista[linea][1]) - 1, -1):
                nombre_cuerda[0] = [nombre_cuerda[0][0], i]
                k = 0
                for j in nombre_cuerda:
                    if k != 9 and k != 0:
                        while abs(nombre_cuerda[k - 1][0] - j[0]) > 1 or abs(nombre_cuerda[k - 1][1] - j[1]) > 1: #movemos tail para que no haya más de 1 de diferencia
                            if nombre_cuerda[k - 1][0] - j[0] > 1 and nombre_cuerda[k - 1][1] - j[1] == 1:
                                j[0] += 1
                                j[1] += 1
                            elif nombre_cuerda[k - 1][0] - j[0] > 1 and nombre_cuerda[k - 1][1] -j[1] == -1:
                                j[0] += 1
                                j[1] -= 1
                            elif nombre_cuerda[k - 1][0] - j[0] < -1 and nombre_cuerda[k - 1][1] - j[1] == 1:
                                j[0] -= 1
                                j[1] += 1
                            elif nombre_cuerda[k - 1][0] - j[0] < -1 and nombre_cuerda[k - 1][1] - j[1] == -1:
                                j[0] -= 1
                                j[1] -= 1
                            elif nombre_cuerda[k - 1][0] -  j[0] == 1 and nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[0] += 1
                                j[1] += 1
                            elif nombre_cuerda[k - 1][0] -  j[0] == 1 and nombre_cuerda[k - 1][1] - j[1] < -1:
                                j[0] += 1
                                j[1] -= 1
                            elif nombre_cuerda[k - 1][0] -  j[0] == -1 and nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[0] -= 1
                                j[1] += 1
                            elif nombre_cuerda[k - 1][0] -  j[0] == -1 and nombre_cuerda[k - 1][1] - j[1] < -1:
                                j[0] -= 1
                                j[1] -= 1
                            if nombre_cuerda[k - 1][0] - j[0] > 1:
                                j[0] += 1
                            elif nombre_cuerda[k - 1][0] -  j[0] < -1:
                                j[0] -= 1
                            if nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[1] += 1
                            elif nombre_cuerda[k - 1][1] -  j[1] < -1:
                                j[1] -= 1
                    if k == 9:
                        while abs(nombre_cuerda[k - 1][0] - j[0]) > 1 or abs(nombre_cuerda[k - 1][1] - j[1]) > 1: #movemos tail para que no haya más de 1 de diferencia
                            if nombre_cuerda[k - 1][0] - j[0] > 1 and nombre_cuerda[k - 1][1] - j[1] == 1:
                                j[0] += 1
                                j[1] += 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] - j[0] > 1 and nombre_cuerda[k - 1][1] -j[1] == -1:
                                j[0] += 1
                                j[1] -= 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] - j[0] < -1 and nombre_cuerda[k - 1][1] - j[1] == 1:
                                j[0] -= 1
                                j[1] += 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] - j[0] < -1 and nombre_cuerda[k - 1][1] - j[1] == -1:
                                j[0] -= 1
                                j[1] -= 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] -  j[0] == 1 and nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[0] += 1
                                j[1] += 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] -  j[0] == 1 and nombre_cuerda[k - 1][1] - j[1] < -1:
                                j[0] += 1
                                j[1] -= 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] -  j[0] == -1 and nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[0] -= 1
                                j[1] += 1
                                posiciones_visitadas_tail.append(j.copy())
                            elif nombre_cuerda[k - 1][0] -  j[0] == -1 and nombre_cuerda[k - 1][1] - j[1] < -1:
                                j[0] -= 1
                                j[1] -= 1
                                posiciones_visitadas_tail.append(j.copy())
                            if nombre_cuerda[k - 1][0] - j[0] > 1:
                                j[0] += 1
                            elif nombre_cuerda[k - 1][0] -  j[0] < -1:
                                j[0] -= 1
                            if nombre_cuerda[k - 1][1] - j[1] > 1:
                                j[1] += 1
                            elif nombre_cuerda[k - 1][1] -  j[1] < -1:
                                j[1] -= 1
                            posiciones_visitadas_tail.append(j.copy())


                    k += 1                
            print("linea", linea, "nombre_cuerda", nombre_cuerda)

        linea += 1
    except:
        finalizado = True


solucion = []
posiciones_visitadas_tail.append([1000, 1000])
for i in posiciones_visitadas_tail:
    if i not in solucion:
        solucion.append(i)
print(len(solucion))
# Out:
# linea 0 nombre_cuerda [[998, 1000], [999, 1000], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000]]
# linea 1 nombre_cuerda [[1000, 1000], [999, 1000], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000]]
# linea 2 nombre_cuerda [[1000, 998], [1000, 999], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000]]
# linea 3 nombre_cuerda [[998, 998], [999, 998], [999, 999], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000]]
# linea 4 nombre_cuerda [[998, 996], [998, 997], [998, 998], [999, 999], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000]]
# linea 5 nombre_cuerda [[996, 996], [997, 996], [997, 997], [998, 998], [999, 999], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000]]
# ...
